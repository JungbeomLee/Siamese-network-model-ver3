# %% [markdown]
# https://sacko.tistory.com/category/Data%20Science/%EB%AC%B8%EA%B3%BC%EC%83%9D%EB%8F%84%20%EC%9D%B4%ED%95%B4%ED%95%98%EB%8A%94%20%EB%94%A5%EB%9F%AC%EB%8B%9D
#
# https://sacko.tistory.com/category/Data%20Science/%EB%AC%B8%EA%B3%BC%EC%83%9D%EC%9D%84%20%EC%9C%84%ED%95%9C%20%EB%94%A5%EB%9F%AC%EB%8B%9D%20%EC%88%98%ED%95%99

# %% [markdown]
# https://simonezz.tistory.com/100
# https://github.com/tensorfreitas/Siamese-Networks-for-One-Shot-Learning/blob/master/train_siamese_network.py
# https://github.com/tensorfreitas/Siamese-Networks-for-One-Shot-Learning/blob/master/siamese_network.py
# https://www.cs.cmu.edu/~rsalakhu/papers/oneshot1.pdf
# https://m.blog.naver.com/ssdyka/221299637545
# https://modulabs.co.kr/blog/tensorflow-custom-trainer/
# https://sihyeon-kim.github.io/neural-networks-and-deep-learning-korean/chapter2.html
# https://towardsdatascience.com/one-shot-learning-with-siamese-networks-using-keras-17f34e75bb3d

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.utils import plot_model
from tensorflow.keras.layers import *
from tensorflow.keras.models import *
from tensorflow.keras.optimizers import SGD,Adam
from tensorflow.keras.optimizers import RMSprop
from google.colab.patches import cv2_imshow
import numpy as np
import os
import cv2
import time
import itertools

# %% [markdown]
# # Model

# %%
from re import X
from keras.engine.training import Model
from keras.api._v2.keras import activations


class Siamese_neural_networks :
    def __init__(self) :
        """
        We initialized all network weights
        in the convolutional layers from a normal distribution with
        zero-mean and a standard deviation of 1e-2

        Biases were also initialized from a normal distribution, 
        but with mean 0.5 and standard deviation 1e-2

        In the fully-connected layers, 
        the biases were initialized in the same way as the convolutional layers, 
        but the weights were drawn from a much wider normal distribution with zero-mean and standard deviation 2e-1
        ==============
        """
        # 가중치값 평균:0, 표준편차 1e-2인 정규분포로 초기화
        self.conv_layer_weight_init = tf.keras.initializers.RandomNormal(mean=0, stddev=0.1)
        # 바이어스 값 평균:0.5, 표준편차:1e-2인 정규분포로 초기화
        self.conv_layer_bias_init = tf.keras.initializers.RandomNormal(mean=0.5, stddev=0.01)

        # 가중치값 평균:0, 표준편차 2e-1인 정규분포로 초기화
        self.dense_layer_weight_init = tf.keras.initializers.RandomNormal(mean=0, stddev=0.2)
        # 바이어스 값 평균:0.5, 표준편차:1e-2인 정규분포로 초기화
        self.dense_layer_bias_init = tf.keras.initializers.RandomNormal(mean=0.5, stddev=0.01)

        self.input_shape = (105, 105, 1)
        self.best_weights = None
    
    def create_network(self) :
        """
        3.1. Model:
        The number of convolutional
        filters is specified as a multiple of 16 to optimize performance. 
        ==============
        필터의 성능을 최적화하기 위해 16의 배수로 지정한다.
        --------------
        Hyperparameter optimization:
        layer-wise L2 regularization penalty λj ∈ [0, 0.1]
        ==============
        각 레이어에 L2 정규화 패널티를 적용하였다. 계층별 L2 정규화 패널티 λj는 [0, 0.1] 범위에 있다.

        가중치 제곱에 L2 정규화 항을 곱한다. 이 값을 모델의 손실함수 binary_crossentropy의 값에 더함으로써
        손실함수는 binary_crossentropy의 값 뿐만 아니라 가중치 제곱항의 값 또한 고려하게 된다.
        가중치의 값이 클수록 손실함수의 값이 커지므로 신경망은 가중치가 작도록 노력할 것이다.
        이를 통해 가중치가 과도하게 커져 발생하는 과대적합을 방지할 수 있다.

        L2 정규화 항의 가중치인 '2e-4', '1e-3'는 타 자료를 참고하여, 
        다른 분들이 이미 논문에 나온 Bayesian optimization framework Whetlab을 통해 구한듯한 값을 사용한 것이다.
        """                                
        convolutional_network = Sequential()
        convolutional_network.add(Conv2D(filters=64, 
                                        kernel_size=(10, 10),
                                        activation='relu',
                                        input_shape=self.input_shape,
                                        # L2 정규화 패널티를 적용
                                        kernel_regularizer = tf.keras.regularizers.L2(2e-4),
                                        # 가중치값 평균:0, 표준편차 1e-2인 정규분포로 초기화
                                        kernel_initializer=self.conv_layer_weight_init,
                                        # 바이어스 값 평균:0.5, 표준편차:1e-2인 정규분포로 초기화
                                        bias_initializer=self.conv_layer_bias_init,
                                        name='Conv_1'))
        
        convolutional_network.add(MaxPooling2D(pool_size=(2,2), name='Maxpooling_1'))

        convolutional_network.add(Conv2D(filters=128, 
                                        kernel_size=(7, 7),
                                        activation='relu',
                                        # L2 정규화 패널티를 적용
                                        kernel_regularizer = tf.keras.regularizers.L2(2e-4),
                                        # 가중치값 평균:0, 표준편차 1e-2인 정규분포로 초기화
                                        kernel_initializer=self.conv_layer_weight_init,
                                        # 바이어스 값 평균:0.5, 표준편차:1e-2인 정규분포로 초기화
                                        bias_initializer=self.conv_layer_bias_init,
                                        name='Conv_2'))
        
        convolutional_network.add(MaxPooling2D(pool_size=(2,2), name='Maxpooling_2'))

        convolutional_network.add(Conv2D(filters=128, 
                                        kernel_size=(4, 4),
                                        activation='relu',
                                        # L2 정규화 패널티를 적용
                                        kernel_regularizer = tf.keras.regularizers.L2(2e-4),
                                        # 가중치값 평균:0, 표준편차 1e-2인 정규분포로 초기화
                                        kernel_initializer=self.conv_layer_weight_init,
                                        # 바이어스 값 평균:0.5, 표준편차:1e-2인 정규분포로 초기화
                                        bias_initializer=self.conv_layer_bias_init,
                                        name='Conv_3'))
        
        convolutional_network.add(MaxPooling2D(pool_size=(2,2), name='Maxpooling_3'))

        convolutional_network.add(Conv2D(filters=256, 
                                        kernel_size=(4, 4),
                                        activation='relu',
                                        # L2 정규화 패널티를 적용
                                        kernel_regularizer = tf.keras.regularizers.L2(2e-4),
                                        # 가중치값 평균:0, 표준편차 1e-2인 정규분포로 초기화
                                        kernel_initializer=self.conv_layer_weight_init,
                                        # 바이어스 값 평균:0.5, 표준편차:1e-2인 정규분포로 초기화
                                        bias_initializer=self.conv_layer_bias_init,
                                        name='Conv_4'))
        
        convolutional_network.add(Flatten())


        convolutional_network.add(Dense(units=4096,
                                        activation='sigmoid',
                                        # L2 정규화 패널티를 적용
                                        kernel_regularizer = tf.keras.regularizers.L2(1e-3),
                                        # 가중치값 평균:0, 표준편차 2e-1인 정규분포로 초기화
                                        kernel_initializer=self.dense_layer_weight_init,
                                        # 바이어스 값 평균:0.5, 표준편차:1e-2인 정규분포로 초기화
                                        bias_initializer=self.dense_layer_bias_init,
                                        name='Dense_1'))
        
        input_a = Input(self.input_shape, name='input_a')
        input_b = Input(self.input_shape, name='input_b')

        encoded_image_1 = convolutional_network(input_a)
        encoded_image_2 = convolutional_network(input_b)

        L1_layer = Lambda(lambda tensors:tf.abs(tensors[0] - tensors[1]))
        L1_distance = L1_layer([encoded_image_1, encoded_image_2])

        output_layer = Dense(units=1,
                             activation='sigmoid',
                             name='output_layer')(L1_distance)

        self.model = Model(inputs=[input_a, input_b], outputs=output_layer)
        """
        Optimization:
        We fix a minibatch size of 128 with learning rate ηj , 
        momentum µj , and L2 regularization weights λj defined layer-wise
        ==============
        우리는 미니배치 크기를 128로 고정하고, 학습률 ηj, 모멘텀 µj, 그리고 L2 정규화 가중치 λj를 계층별로 정의한다.

        논문에 나온 Optimizer의 형태와 가장 비슷한 SDG를 사용한다.
        --------------
        Hyperparameter optimization :
        we set the layerwise learning rate ηj ∈ [1e-4, 1e-1], 
        layer-wise momentum µj ∈ [0, 1]
        ==============
        모멘텀은 모든 계층에서 0.5에서 시작하여, 
        각 에포크마다 선형적으로 증가하여 j번째 계층에 대한 개별 모멘텀 항 µj 값을 도달하게 했다.

        논문을 구현한 다른 코드를 참고하며, learning_rate는 1e-1, momentum은 5e-1로 설정한다.
        --------------
        Loss function :
        We impose a regularized cross-entropy objective on our binary classifier of the following form:
        ==============
        loss 함수로 binary_crossentropy를 사용한다
        """
        optimizer = tf.keras.optimizers.experimental.SGD(learning_rate=0.1, momentum=0.5)

        self.model.compile(loss = 'binary_crossentropy', metrics=['binary_accuracy'], optimizer=optimizer)

        return self.model
    
    def train_model(self, siamese_model, data) :
        self.x_ONE_train, self.x_TWO_train, self.y_train = data
        with tf.GradientTape() as tape :
            self.y_pred = siamese_model([self.x_ONE_train, self.x_TWO_train], training=True)
            self.y_pred = tf.squeeze(self.y_pred, axis=-1) 

            loss_fn = tf.keras.losses.BinaryCrossentropy()
            acc_fn = tf.keras.metrics.BinaryAccuracy()

            loss = loss_fn(self.y_train, self.y_pred)
            acc = acc_fn(self.y_train, self.y_pred)
        gradients = tape.gradient(loss, siamese_model.trainable_weights)
        siamese_model.optimizer.apply_gradients(zip(gradients, siamese_model.trainable_weights))
    
        return {"loss": loss, "accuracy": acc}

# %% [markdown]
# # Create dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import natsort
start = time.time()
path = "/content/drive/MyDrive/A.아이/images/ATandT/"
dataset_listdir = natsort.natsorted(os.listdir(path))
print("time :", time.time() - start)
# Out:
# time : 0.0017337799072265625

# %%
start = time.time()
img_list, img_label = [], []
for folder_name in dataset_listdir :
    image_name_list = natsort.natsorted(os.listdir(path+folder_name))
    for image_name in image_name_list :
        img = cv2.imread(path+folder_name+'/'+image_name)
        resized_image = cv2.resize(img, (105, 105))
        face_image = cv2.cvtColor(resized_image, cv2.COLOR_BGR2GRAY)
        face_image = cv2.equalizeHist(face_image)
        img_list.append(face_image)
        img_label.append(folder_name)
print("time :", time.time() - start)
len(img_list), len(img_label)
# Out:
# time : 0.6184697151184082
# (400, 400)

# %%
def generate_train_image_pairs(images_dataset, labels_dataset):
    unique_labels = np.unique(labels_dataset)
    label_wise_indices = dict()
    for label in unique_labels:
        label_wise_indices.setdefault(label,
                                      [index for index, curr_label in enumerate(labels_dataset) if
                                       label == curr_label])
    
    pair_images = []
    pair_labels = []
    for index, image in enumerate(images_dataset):
        pos_indices = label_wise_indices.get(labels_dataset[index])
        pos_image = images_dataset[np.random.choice(pos_indices)]
        pair_images.append((image, pos_image))
        pair_labels.append(1)

        neg_indices = np.where(labels_dataset != labels_dataset[index])
        neg_image = images_dataset[np.random.choice(neg_indices[0])]
        pair_images.append((image, neg_image))
        pair_labels.append(0)
    return np.array(pair_images), np.array(pair_labels)

# %%
img_list_np = np.array(img_list)
train_image_np = img_list_np[:300]

img_label_np = np.array(img_label)
train_label_np = img_label_np[:300]

# %%
# create train image list
x_train_pairs, y_train_pairs = generate_train_image_pairs(train_image_np, train_label_np)
x_train_pairs.shape ,y_train_pairs.shape
# Out:
# ((600, 2, 105, 105), (600,))

# %%
unique, counts = np.unique(np.reshape(y_train_pairs, (x_train_pairs.shape[0],)), return_counts=True)
dict(zip(unique, counts))
# Out:
# {0: 300, 1: 300}

# %%
img_list_np = np.array(img_list)
test_image_np = img_list_np[300:]

img_label_np = np.array(img_label)
test_label_np = img_label_np[300:]

# %%
# create test image list
x_test_pairs, y_test_pairs = generate_train_image_pairs(test_image_np, test_label_np)
x_test_pairs.shape ,y_test_pairs.shape
# Out:
# ((200, 2, 105, 105), (200,))

# %%
unique, counts = np.unique(np.reshape(y_test_pairs, (x_test_pairs.shape[0],)), return_counts=True)
dict(zip(unique, counts))
# Out:
# {0: 100, 1: 100}

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((x_train_pairs, y_train_pairs))
train_dataset = train_dataset.shuffle(buffer_size=1024).batch(128)

val_dataset = tf.data.Dataset.from_tensor_slices((x_test_pairs, y_test_pairs))
val_dataset = val_dataset.batch(128)

# %% [markdown]
# # Training

# %%
create_Siamese_network_model = Siamese_neural_networks()
model = create_Siamese_network_model.create_network()
plot_model(model, show_shapes=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/initializers/initializers.py:120: UserWarning: The initializer RandomNormal is unseeded and being called multiple times, which will return identical values each time (even if the initializer is unseeded). Please update your code to provide a seed to the initializer, or avoid using the same initalizer instance more than once.
#   warnings.warn(

# %%
best_val_loss = float("inf")
count = 0
for epoch in range(200):
    print("\nStart of epoch %d" % (epoch,))
    # Iterate over the pairs of the dataset.
    for step, (x_batch_train, y_batch_train) in enumerate(train_dataset):
        x1_batch_train = x_batch_train[:, 0]
        x2_batch_train = x_batch_train[:, 1]

        logs = create_Siamese_network_model.train_model(model, data=(x1_batch_train, x2_batch_train, y_batch_train))

        if step % 200 == 0:
            print("Training loss (for one batch) at step %d: %.4f"% (step, float(logs["loss"])))
            print("Seen so far: %d samples, accuracy: %.4f"% ((step + 1) * 128, float(logs["accuracy"])))
    
    val_loss = 0
    val_acc = 0
    for x_batch_val, y_batch_val in val_dataset:
        x1_batch_val = x_batch_val[:, 0]
        x2_batch_val = x_batch_val[:, 1]

        val_pred = create_Siamese_network_model.train_model(model, data=(x1_batch_val, x2_batch_val, y_batch_val))
        val_loss += val_pred["loss"]
        val_acc += val_pred["accuracy"]
    
    val_loss /= len(val_dataset)
    val_acc /= len(val_dataset)
    print("Validation loss: %.4f" % (float(val_loss),))
    print("Validation accuracy: %.4f" % (float(val_acc),))

    # Decay learning rate
    lr = float(model.optimizer.learning_rate)
    # Increase momentum
    momentum = min(float(model.optimizer.momentum) + 0.01, 0.9)
    optimizer = tf.keras.optimizers.SGD(learning_rate=lr*0.99, momentum=momentum, nesterov=True)
    model.optimizer = optimizer

    # Check early stopping condition
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        count = 0
        create_Siamese_network_model.best_weights = model.get_weights()  # Save the best weights
    else:
        count += 1
        if count >= 20:
            print("Early stopping")
            break
# Out:
# Start of epoch 0
# WARNING:tensorflow:5 out of the last 5 calls to <function _BaseOptimizer._update_step_xla at 0x7efbaf2860e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function _BaseOptimizer._update_step_xla at 0x7efbaf2860e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Training loss (for one batch) at step 0: 0.7759
# Seen so far: 128 samples, accuracy: 0.3906
# Validation loss: 0.6377
# Validation accuracy: 0.5569
#
# Start of epoch 1
# Training loss (for one batch) at step 0: 0.5966
# Seen so far: 128 samples, accuracy: 0.6562
# Validation loss: 0.5728
# Validation accuracy: 0.6797
#
# Start of epoch 2
# Training loss (for one batch) at step 0: 0.5831
# Seen so far: 128 samples, accuracy: 0.7500
# Validation loss: 0.5249
# Validation accuracy: 0.7465
#
# Start of epoch 3
# Training loss (for one batch) at step 0: 0.4909
# Seen so far: 128 samples, accuracy: 0.8047
# Validation loss: 0.4906
# Validation accuracy: 0.7704
#
# Start of epoch 4
# Training loss (for one batch) at step 0: 0.4794
# Seen so far: 128 samples, accuracy: 0.8281
# Validation loss: 0.4655
# Validation accuracy: 0.8199
#
# Start of epoch 5
# Training loss (for one batch) at step 0: 0.4764
# Seen so far: 128 samples, accuracy: 0.7969
# Validation loss: 0.4362
# Validation accuracy: 0.8533
#
# Start of epoch 6
# Training loss (for one batch) at step 0: 0.4016
# Seen so far: 128 samples, accuracy: 0.9062
# Validation loss: 0.4193
# Validation accuracy: 0.8611
#
# Start of epoch 7
# Training loss (for one batch) at step 0: 0.3865
# Seen so far: 128 samples, accuracy: 0.9062
# Validation loss: 0.4020
# Validation accuracy: 0.8650
#
# Start of epoch 8
# Training loss (for one batch) at step 0: 0.4298
# Seen so far: 128 samples, accuracy: 0.8359
# Validation loss: 0.3882
# Validation accuracy: 0.8689
#
# Start of epoch 9
# Training loss (for one batch) at step 0: 0.3566
# Seen so far: 128 samples, accuracy: 0.9141
# Validation loss: 0.3758
# Validation accuracy: 0.8759
#
# Start of epoch 10
# Training loss (for one batch) at step 0: 0.3469
# Seen so far: 128 samples, accuracy: 0.8828
# Validation loss: 0.3637
# Validation accuracy: 0.8967
#
# Start of epoch 11
# Training loss (for one batch) at step 0: 0.3431
# Seen so far: 128 samples, accuracy: 0.8750
# Validation loss: 0.3510
# Validation accuracy: 0.8898
#
# Start of epoch 12
# Training loss (for one batch) at step 0: 0.3793
# Seen so far: 128 samples, accuracy: 0.8516
# Validation loss: 0.3417
# Validation accuracy: 0.9006
#
# Start of epoch 13
# Training loss (for one batch) at step 0: 0.3605
# Seen so far: 128 samples, accuracy: 0.8516
# Validation loss: 0.3322
# Validation accuracy: 0.9006
#
# Start of epoch 14
# Training loss (for one batch) at step 0: 0.3210
# Seen so far: 128 samples, accuracy: 0.9219
# Validation loss: 0.3264
# Validation accuracy: 0.9006
#
# Start of epoch 15
# Training loss (for one batch) at step 0: 0.3603
# Seen so far: 128 samples, accuracy: 0.8750
# Validation loss: 0.3161
# Validation accuracy: 0.9084
#
# Start of epoch 16
# Training loss (for one batch) at step 0: 0.2983
# Seen so far: 128 samples, accuracy: 0.9062
# Validation loss: 0.3076
# Validation accuracy: 0.9084
#
# Start of epoch 17
# Training loss (for one batch) at step 0: 0.2950
# Seen so far: 128 samples, accuracy: 0.9219
# Validation loss: 0.3023
# Validation accuracy: 0.9084
#
# Start of epoch 18
# Training loss (for one batch) at step 0: 0.2818
# Seen so far: 128 samples, accuracy: 0.9453
# Validation loss: 0.2944
# Validation accuracy: 0.9123
#
# Start of epoch 19
# Training loss (for one batch) at step 0: 0.2748
# Seen so far: 128 samples, accuracy: 0.9297
# Validation loss: 0.2907
# Validation accuracy: 0.9084
#
# Start of epoch 20
# Training loss (for one batch) at step 0: 0.2682
# Seen so far: 128 samples, accuracy: 0.9453
# Validation loss: 0.2836
# Validation accuracy: 0.9054
#
# Start of epoch 21
# Training loss (for one batch) at step 0: 0.2653
# Seen so far: 128 samples, accuracy: 0.9531
# Validation loss: 0.2783
# Validation accuracy: 0.9093
#
# Start of epoch 22
# Training loss (for one batch) at step 0: 0.2773
# Seen so far: 128 samples, accuracy: 0.9062
# Validation loss: 0.2736
# Validation accuracy: 0.9054
#
# Start of epoch 23
# Training loss (for one batch) at step 0: 0.3066
# Seen so far: 128 samples, accuracy: 0.8672
# Validation loss: 0.2713
# Validation accuracy: 0.9123
#
# Start of epoch 24
# Training loss (for one batch) at step 0: 0.2536
# Seen so far: 128 samples, accuracy: 0.9297
# Validation loss: 0.2654
# Validation accuracy: 0.9054
#
# Start of epoch 25
# Training loss (for one batch) at step 0: 0.2743
# Seen so far: 128 samples, accuracy: 0.9297
# Validation loss: 0.2635
# Validation accuracy: 0.9123
#
# Start of epoch 26
# Training loss (for one batch) at step 0: 0.2849
# Seen so far: 128 samples, accuracy: 0.9141
# Validation loss: 0.2591
# Validation accuracy: 0.9123
#
# Start of epoch 27
# Training loss (for one batch) at step 0: 0.2395
# Seen so far: 128 samples, accuracy: 0.9531
# Validation loss: 0.2549
# Validation accuracy: 0.9123
#
# Start of epoch 28
# Training loss (for one batch) at step 0: 0.2473
# Seen so far: 128 samples, accuracy: 0.9688
# Validation loss: 0.2502
# Validation accuracy: 0.9093
#
# Start of epoch 29
# Training loss (for one batch) at step 0: 0.2430
# Seen so far: 128 samples, accuracy: 0.9531
# Validation loss: 0.2473
# Validation accuracy: 0.9132
#
# Start of epoch 30
# Training loss (for one batch) at step 0: 0.2395
# Seen so far: 128 samples, accuracy: 0.9531
# Validation loss: 0.2462
# Validation accuracy: 0.9123
#
# Start of epoch 31
# Training loss (for one batch) at step 0: 0.2291
# Seen so far: 128 samples, accuracy: 0.9453
# Validation loss: 0.2416
# Validation accuracy: 0.9201
#
# Start of epoch 32
# Training loss (for one batch) at step 0: 0.2694
# Seen so far: 128 samples, accuracy: 0.9297
# Validation loss: 0.2390
# Validation accuracy: 0.9201
#
# Start of epoch 33
# Training loss (for one batch) at step 0: 0.2102
# Seen so far: 128 samples, accuracy: 0.9688
# Validation loss: 0.2368
# Validation accuracy: 0.9162
#
# Start of epoch 34
# Training loss (for one batch) at step 0: 0.2590
# Seen so far: 128 samples, accuracy: 0.9375
# Validation loss: 0.2334
# Validation accuracy: 0.9162
#
# Start of epoch 35
# Training loss (for one batch) at step 0: 0.2377
# Seen so far: 128 samples, accuracy: 0.9453
# Validation loss: 0.2327
# Validation accuracy: 0.9162
#
# Start of epoch 36
# Training loss (for one batch) at step 0: 0.2066
# Seen so far: 128 samples, accuracy: 0.9766
# Validation loss: 0.2293
# Validation accuracy: 0.9201
#
# Start of epoch 37
# Training loss (for one batch) at step 0: 0.1955
# Seen so far: 128 samples, accuracy: 0.9688
# Validation loss: 0.2267
# Validation accuracy: 0.9201
#
# Start of epoch 38
# Training loss (for one batch) at step 0: 0.1936
# Seen so far: 128 samples, accuracy: 0.9766
# Validation loss: 0.2254
# Validation accuracy: 0.9201
#
# Start of epoch 39
# Training loss (for one batch) at step 0: 0.2117
# Seen so far: 128 samples, accuracy: 0.9609
# Validation loss: 0.2265
# Validation accuracy: 0.9232
#
# Start of epoch 40
# Training loss (for one batch) at step 0: 0.2003
# Seen so far: 128 samples, accuracy: 0.9688
# Validation loss: 0.2218
# Validation accuracy: 0.9162
#
# Start of epoch 41
# Training loss (for one batch) at step 0: 0.2063
# Seen so far: 128 samples, accuracy: 0.9766
# Validation loss: 0.2211
# Validation accuracy: 0.9201
#
# Start of epoch 42
# Training loss (for one batch) at step 0: 0.2183
# Seen so far: 128 samples, accuracy: 0.9531
# Validation loss: 0.2177
# Validation accuracy: 0.9162
#
# Start of epoch 43
# Training loss (for one batch) at step 0: 0.1985
# Seen so far: 128 samples, accuracy: 0.9531
# Validation loss: 0.2164
# Validation accuracy: 0.9162
#
# Start of epoch 44
# Training loss (for one batch) at step 0: 0.1693
# Seen so far: 128 samples, accuracy: 0.9609
# Validation loss: 0.2198
# Validation accuracy: 0.9232
#
# Start of epoch 45
# Training loss (for one batch) at step 0: 0.1737
# Seen so far: 128 samples, accuracy: 0.9922
# Validation loss: 0.2129
# Validation accuracy: 0.9201
#
# Start of epoch 46
# Training loss (for one batch) at step 0: 0.2028
# Seen so far: 128 samples, accuracy: 0.9609
# Validation loss: 0.2122
# Validation accuracy: 0.9271
#
# Start of epoch 47
# Training loss (for one batch) at step 0: 0.1808
# Seen so far: 128 samples, accuracy: 0.9609
# Validation loss: 0.2095
# Validation accuracy: 0.9201
#
# Start of epoch 48
# Training loss (for one batch) at step 0: 0.1768
# Seen so far: 128 samples, accuracy: 0.9688
# Validation loss: 0.2090
# Validation accuracy: 0.9271
#
# Start of epoch 49
# Training loss (for one batch) at step 0: 0.1985
# Seen so far: 128 samples, accuracy: 0.9531
# Validation loss: 0.2068
# Validation accuracy: 0.9201
#
# Start of epoch 50
# Training loss (for one batch) at step 0: 0.1917
# Seen so far: 128 samples, accuracy: 0.9531
# Validation loss: 0.2063
# Validation accuracy: 0.9201
#
# Start of epoch 51
# Training loss (for one batch) at step 0: 0.2191
# Seen so far: 128 samples, accuracy: 0.9531
# Validation loss: 0.2046
# Validation accuracy: 0.9201
#
# Start of epoch 52
# Training loss (for one batch) at step 0: 0.1619
# Seen so far: 128 samples, accuracy: 0.9688
# Validation loss: 0.2031
# Validation accuracy: 0.9201
#
# Start of epoch 53
# Training loss (for one batch) at step 0: 0.1857
# Seen so far: 128 samples, accuracy: 0.9688
# Validation loss: 0.2019
# Validation accuracy: 0.9201
#
# Start of epoch 54
# Training loss (for one batch) at step 0: 0.1752
# Seen so far: 128 samples, accuracy: 0.9688
# Validation loss: 0.2006
# Validation accuracy: 0.9201
#
# Start of epoch 55
# Training loss (for one batch) at step 0: 0.2039
# Seen so far: 128 samples, accuracy: 0.9453
# Validation loss: 0.1996
# Validation accuracy: 0.9240
#
# Start of epoch 56
# Training loss (for one batch) at step 0: 0.1743
# Seen so far: 128 samples, accuracy: 0.9609
# Validation loss: 0.1980
# Validation accuracy: 0.9240
#
# Start of epoch 57
# Training loss (for one batch) at step 0: 0.1828
# Seen so far: 128 samples, accuracy: 0.9766
# Validation loss: 0.1967
# Validation accuracy: 0.9240
#
# Start of epoch 58
# Training loss (for one batch) at step 0: 0.1565
# Seen so far: 128 samples, accuracy: 0.9531
# Validation loss: 0.1956
# Validation accuracy: 0.9240
#
# Start of epoch 59
# Training loss (for one batch) at step 0: 0.1507
# Seen so far: 128 samples, accuracy: 0.9844
# Validation loss: 0.1951
# Validation accuracy: 0.9240
#
# Start of epoch 60
# Training loss (for one batch) at step 0: 0.1641
# Seen so far: 128 samples, accuracy: 0.9766
# Validation loss: 0.1944
# Validation accuracy: 0.9240
#
# Start of epoch 61
# Training loss (for one batch) at step 0: 0.1673
# Seen so far: 128 samples, accuracy: 0.9688
# Validation loss: 0.1931
# Validation accuracy: 0.9240
#
# Start of epoch 62
# Training loss (for one batch) at step 0: 0.1679
# Seen so far: 128 samples, accuracy: 0.9609
# Validation loss: 0.1925
# Validation accuracy: 0.9310
#
# Start of epoch 63
# Training loss (for one batch) at step 0: 0.1831
# Seen so far: 128 samples, accuracy: 0.9531
# Validation loss: 0.1912
# Validation accuracy: 0.9240
#
# Start of epoch 64
# Training loss (for one batch) at step 0: 0.1595
# Seen so far: 128 samples, accuracy: 0.9766
# Validation loss: 0.1902
# Validation accuracy: 0.9240
#
# Start of epoch 65
# Training loss (for one batch) at step 0: 0.1419
# Seen so far: 128 samples, accuracy: 0.9766
# Validation loss: 0.1889
# Validation accuracy: 0.9240
#
# Start of epoch 66
# Training loss (for one batch) at step 0: 0.1583
# Seen so far: 128 samples, accuracy: 0.9766
# Validation loss: 0.1881
# Validation accuracy: 0.9201
#
# Start of epoch 67
# Training loss (for one batch) at step 0: 0.1701
# Seen so far: 128 samples, accuracy: 0.9688
# Validation loss: 0.1872
# Validation accuracy: 0.9201
#
# Start of epoch 68
# Training loss (for one batch) at step 0: 0.1481
# Seen so far: 128 samples, accuracy: 0.9688
# Validation loss: 0.1867
# Validation accuracy: 0.9310
#
# Start of epoch 69
# Training loss (for one batch) at step 0: 0.1586
# Seen so far: 128 samples, accuracy: 0.9531
# Validation loss: 0.1853
# Validation accuracy: 0.9201
#
# Start of epoch 70
# Training loss (for one batch) at step 0: 0.1562
# Seen so far: 128 samples, accuracy: 0.9766
# Validation loss: 0.1848
# Validation accuracy: 0.9310
#
# Start of epoch 71
# Training loss (for one batch) at step 0: 0.1733
# Seen so far: 128 samples, accuracy: 0.9688
# Validation loss: 0.1836
# Validation accuracy: 0.9201
#
# Start of epoch 72
# Training loss (for one batch) at step 0: 0.1607
# Seen so far: 128 samples, accuracy: 0.9688
# Validation loss: 0.1835
# Validation accuracy: 0.9310
#
# Start of epoch 73
# Training loss (for one batch) at step 0: 0.1579
# Seen so far: 128 samples, accuracy: 0.9688
# Validation loss: 0.1824
# Validation accuracy: 0.9271
#
# Start of epoch 74
# Training loss (for one batch) at step 0: 0.1177
# Seen so far: 128 samples, accuracy: 0.9766
# Validation loss: 0.1816
# Validation accuracy: 0.9271
#
# Start of epoch 75
# Training loss (for one batch) at step 0: 0.1473
# Seen so far: 128 samples, accuracy: 0.9922
# Validation loss: 0.1809
# Validation accuracy: 0.9271
#
# Start of epoch 76
# Training loss (for one batch) at step 0: 0.1373
# Seen so far: 128 samples, accuracy: 0.9844
# Validation loss: 0.1801
# Validation accuracy: 0.9201
#
# Start of epoch 77
# Training loss (for one batch) at step 0: 0.1638
# Seen so far: 128 samples, accuracy: 0.9609
# Validation loss: 0.1794
# Validation accuracy: 0.9271
#
# Start of epoch 78
# Training loss (for one batch) at step 0: 0.1437
# Seen so far: 128 samples, accuracy: 0.9922
# Validation loss: 0.1790
# Validation accuracy: 0.9310
#
# Start of epoch 79
# Training loss (for one batch) at step 0: 0.1441
# Seen so far: 128 samples, accuracy: 0.9844
# Validation loss: 0.1780
# Validation accuracy: 0.9271
#
# Start of epoch 80
# Training loss (for one batch) at step 0: 0.1772
# Seen so far: 128 samples, accuracy: 0.9531
# Validation loss: 0.1776
# Validation accuracy: 0.9310
#
# Start of epoch 81
# Training loss (for one batch) at step 0: 0.1292
# Seen so far: 128 samples, accuracy: 0.9844
# Validation loss: 0.1769
# Validation accuracy: 0.9310
#
# Start of epoch 82
# Training loss (for one batch) at step 0: 0.1564
# Seen so far: 128 samples, accuracy: 0.9688
# Validation loss: 0.1763
# Validation accuracy: 0.9379
#
# Start of epoch 83
# Training loss (for one batch) at step 0: 0.1253
# Seen so far: 128 samples, accuracy: 0.9922
# Validation loss: 0.1756
# Validation accuracy: 0.9310
#
# Start of epoch 84
# Training loss (for one batch) at step 0: 0.1230
# Seen so far: 128 samples, accuracy: 0.9844
# Validation loss: 0.1750
# Validation accuracy: 0.9310
#
# Start of epoch 85
# Training loss (for one batch) at step 0: 0.1412
# Seen so far: 128 samples, accuracy: 0.9844
# Validation loss: 0.1744
# Validation accuracy: 0.9379
#
# Start of epoch 86
# Training loss (for one batch) at step 0: 0.1357
# Seen so far: 128 samples, accuracy: 0.9844
# Validation loss: 0.1738
# Validation accuracy: 0.9340
#
# Start of epoch 87
# Training loss (for one batch) at step 0: 0.1357
# Seen so far: 128 samples, accuracy: 0.9766
# Validation loss: 0.1733
# Validation accuracy: 0.9379
#
# Start of epoch 88
# Training loss (for one batch) at step 0: 0.1721
# Seen so far: 128 samples, accuracy: 0.9531
# Validation loss: 0.1728
# Validation accuracy: 0.9379
#
# Start of epoch 89
# Training loss (for one batch) at step 0: 0.1487
# Seen so far: 128 samples, accuracy: 0.9844
# Validation loss: 0.1722
# Validation accuracy: 0.9340
#
# Start of epoch 90
# Training loss (for one batch) at step 0: 0.1272
# Seen so far: 128 samples, accuracy: 1.0000
# Validation loss: 0.1716
# Validation accuracy: 0.9340
#
# Start of epoch 91
# Training loss (for one batch) at step 0: 0.1876
# Seen so far: 128 samples, accuracy: 0.9453
# Validation loss: 0.1712
# Validation accuracy: 0.9379
#
# Start of epoch 92
# Training loss (for one batch) at step 0: 0.1360
# Seen so far: 128 samples, accuracy: 0.9766
# Validation loss: 0.1707
# Validation accuracy: 0.9340
#
# Start of epoch 93
# Training loss (for one batch) at step 0: 0.1326
# Seen so far: 128 samples, accuracy: 0.9844
# Validation loss: 0.1701
# Validation accuracy: 0.9379
#
# Start of epoch 94
# Training loss (for one batch) at step 0: 0.1542
# Seen so far: 128 samples, accuracy: 0.9766
# Validation loss: 0.1696
# Validation accuracy: 0.9340
#
# Start of epoch 95
# Training loss (for one batch) at step 0: 0.1470
# Seen so far: 128 samples, accuracy: 0.9688
# Validation loss: 0.1692
# Validation accuracy: 0.9340
#
# Start of epoch 96
# Training loss (for one batch) at step 0: 0.1313
# Seen so far: 128 samples, accuracy: 0.9766
# Validation loss: 0.1687
# Validation accuracy: 0.9340
#
# Start of epoch 97
# Training loss (for one batch) at step 0: 0.1223
# Seen so far: 128 samples, accuracy: 0.9766
# Validation loss: 0.1682
# Validation accuracy: 0.9340
#
# Start of epoch 98
# Training loss (for one batch) at step 0: 0.1612
# Seen so far: 128 samples, accuracy: 0.9688
# Validation loss: 0.1677
# Validation accuracy: 0.9379
#
# Start of epoch 99
# Training loss (for one batch) at step 0: 0.1533
# Seen so far: 128 samples, accuracy: 0.9531
# Validation loss: 0.1674
# Validation accuracy: 0.9379
#
# Start of epoch 100
# Training loss (for one batch) at step 0: 0.1092
# Seen so far: 128 samples, accuracy: 1.0000
# Validation loss: 0.1668
# Validation accuracy: 0.9379
#
# Start of epoch 101
# Training loss (for one batch) at step 0: 0.1135
# Seen so far: 128 samples, accuracy: 0.9922
# Validation loss: 0.1664
# Validation accuracy: 0.9379
#
# Start of epoch 102
# Training loss (for one batch) at step 0: 0.1107
# Seen so far: 128 samples, accuracy: 1.0000
# Validation loss: 0.1659
# Validation accuracy: 0.9379
#
# Start of epoch 103
# Training loss (for one batch) at step 0: 0.1086
# Seen so far: 128 samples, accuracy: 0.9922
# Validation loss: 0.1654
# Validation accuracy: 0.9379
#
# Start of epoch 104
# Training loss (for one batch) at step 0: 0.1081
# Seen so far: 128 samples, accuracy: 0.9766
# Validation loss: 0.1650
# Validation accuracy: 0.9379
#
# Start of epoch 105
# Training loss (for one batch) at step 0: 0.1183
# Seen so far: 128 samples, accuracy: 0.9844
# Validation loss: 0.1645
# Validation accuracy: 0.9418
#
# Start of epoch 106
# Training loss (for one batch) at step 0: 0.1372
# Seen so far: 128 samples, accuracy: 0.9766
# Validation loss: 0.1643
# Validation accuracy: 0.9379
#
# Start of epoch 107
# Training loss (for one batch) at step 0: 0.1707
# Seen so far: 128 samples, accuracy: 0.9609
# Validation loss: 0.1642
# Validation accuracy: 0.9379
#
# Start of epoch 108
# Training loss (for one batch) at step 0: 0.1325
# Seen so far: 128 samples, accuracy: 0.9844
# Validation loss: 0.1635
# Validation accuracy: 0.9379
#
# Start of epoch 109
# Training loss (for one batch) at step 0: 0.1294
# Seen so far: 128 samples, accuracy: 0.9844
# Validation loss: 0.1635
# Validation accuracy: 0.9418
#
# Start of epoch 110
# Training loss (for one batch) at step 0: 0.1472
# Seen so far: 128 samples, accuracy: 0.9844
# Validation loss: 0.1630
# Validation accuracy: 0.9379
#
# Start of epoch 111
# Training loss (for one batch) at step 0: 0.1332
# Seen so far: 128 samples, accuracy: 0.9922
# Validation loss: 0.1624
# Validation accuracy: 0.9379
#
# Start of epoch 112
# Training loss (for one batch) at step 0: 0.1437
# Seen so far: 128 samples, accuracy: 0.9766
# Validation loss: 0.1622
# Validation accuracy: 0.9418
#
# Start of epoch 113
# Training loss (for one batch) at step 0: 0.1259
# Seen so far: 128 samples, accuracy: 0.9766
# Validation loss: 0.1617
# Validation accuracy: 0.9379
#
# Start of epoch 114
# Training loss (for one batch) at step 0: 0.1452
# Seen so far: 128 samples, accuracy: 0.9766
# Validation loss: 0.1614
# Validation accuracy: 0.9379
#
# Start of epoch 115
# Training loss (for one batch) at step 0: 0.1212
# Seen so far: 128 samples, accuracy: 0.9922
# Validation loss: 0.1611
# Validation accuracy: 0.9379
#
# Start of epoch 116
# Training loss (for one batch) at step 0: 0.1455
# Seen so far: 128 samples, accuracy: 0.9844
# Validation loss: 0.1607
# Validation accuracy: 0.9379
#
# Start of epoch 117
# Training loss (for one batch) at step 0: 0.1325
# Seen so far: 128 samples, accuracy: 0.9922
# Validation loss: 0.1605
# Validation accuracy: 0.9379
#
# Start of epoch 118
# Training loss (for one batch) at step 0: 0.1250
# Seen so far: 128 samples, accuracy: 0.9922
# Validation loss: 0.1601
# Validation accuracy: 0.9418
#
# Start of epoch 119
# Training loss (for one batch) at step 0: 0.1006
# Seen so far: 128 samples, accuracy: 0.9922
# Validation loss: 0.1599
# Validation accuracy: 0.9418
#
# Start of epoch 120
# Training loss (for one batch) at step 0: 0.1190
# Seen so far: 128 samples, accuracy: 0.9844
# Validation loss: 0.1597
# Validation accuracy: 0.9379
#
# Start of epoch 121
# Training loss (for one batch) at step 0: 0.1213
# Seen so far: 128 samples, accuracy: 0.9922
# Validation loss: 0.1591
# Validation accuracy: 0.9379
#
# Start of epoch 122
# Training loss (for one batch) at step 0: 0.1191
# Seen so far: 128 samples, accuracy: 1.0000
# Validation loss: 0.1589
# Validation accuracy: 0.9379
#
# Start of epoch 123
# Training loss (for one batch) at step 0: 0.1254
# Seen so far: 128 samples, accuracy: 0.9922
# Validation loss: 0.1585
# Validation accuracy: 0.9379
#
# Start of epoch 124
# Training loss (for one batch) at step 0: 0.1200
# Seen so far: 128 samples, accuracy: 0.9844
# Validation loss: 0.1583
# Validation accuracy: 0.9379
#
# Start of epoch 125
# Training loss (for one batch) at step 0: 0.1510
# Seen so far: 128 samples, accuracy: 0.9688
# Validation loss: 0.1580
# Validation accuracy: 0.9379
#
# Start of epoch 126
# Training loss (for one batch) at step 0: 0.1332
# Seen so far: 128 samples, accuracy: 0.9766
# Validation loss: 0.1577
# Validation accuracy: 0.9379
#
# Start of epoch 127
# Training loss (for one batch) at step 0: 0.1140
# Seen so far: 128 samples, accuracy: 0.9922
# Validation loss: 0.1575
# Validation accuracy: 0.9379
#
# Start of epoch 128
# Training loss (for one batch) at step 0: 0.1156
# Seen so far: 128 samples, accuracy: 0.9844
# Validation loss: 0.1572
# Validation accuracy: 0.9379
#
# Start of epoch 129
# Training loss (for one batch) at step 0: 0.1306
# Seen so far: 128 samples, accuracy: 0.9844
# Validation loss: 0.1570
# Validation accuracy: 0.9379
#
# Start of epoch 130
# Training loss (for one batch) at step 0: 0.1192
# Seen so far: 128 samples, accuracy: 0.9922
# Validation loss: 0.1566
# Validation accuracy: 0.9379
#
# Start of epoch 131
# Training loss (for one batch) at step 0: 0.1207
# Seen so far: 128 samples, accuracy: 0.9844
# Validation loss: 0.1563
# Validation accuracy: 0.9379
#
# Start of epoch 132
# Training loss (for one batch) at step 0: 0.1450
# Seen so far: 128 samples, accuracy: 0.9844
# Validation loss: 0.1561
# Validation accuracy: 0.9379
#
# Start of epoch 133
# Training loss (for one batch) at step 0: 0.0925
# Seen so far: 128 samples, accuracy: 1.0000
# Validation loss: 0.1558
# Validation accuracy: 0.9379
#
# Start of epoch 134
# Training loss (for one batch) at step 0: 0.1171
# Seen so far: 128 samples, accuracy: 0.9922
# Validation loss: 0.1555
# Validation accuracy: 0.9379
#
# Start of epoch 135
# Training loss (for one batch) at step 0: 0.1021
# Seen so far: 128 samples, accuracy: 1.0000
# Validation loss: 0.1552
# Validation accuracy: 0.9379
#
# Start of epoch 136
# Training loss (for one batch) at step 0: 0.1108
# Seen so far: 128 samples, accuracy: 0.9922
# Validation loss: 0.1550
# Validation accuracy: 0.9379
#
# Start of epoch 137
# Training loss (for one batch) at step 0: 0.1219
# Seen so far: 128 samples, accuracy: 0.9766
# Validation loss: 0.1548
# Validation accuracy: 0.9379
#
# Start of epoch 138
# Training loss (for one batch) at step 0: 0.1137
# Seen so far: 128 samples, accuracy: 0.9844
# Validation loss: 0.1545
# Validation accuracy: 0.9379
#
# Start of epoch 139
# Training loss (for one batch) at step 0: 0.1086
# Seen so far: 128 samples, accuracy: 0.9844
# Validation loss: 0.1544
# Validation accuracy: 0.9418
#
# Start of epoch 140
# Training loss (for one batch) at step 0: 0.1259
# Seen so far: 128 samples, accuracy: 0.9766
# Validation loss: 0.1543
# Validation accuracy: 0.9379
#
# Start of epoch 141
# Training loss (for one batch) at step 0: 0.1005
# Seen so far: 128 samples, accuracy: 0.9922
# Validation loss: 0.1539
# Validation accuracy: 0.9379
#
# Start of epoch 142
# Training loss (for one batch) at step 0: 0.1049
# Seen so far: 128 samples, accuracy: 1.0000
# Validation loss: 0.1538
# Validation accuracy: 0.9418
#
# Start of epoch 143
# Training loss (for one batch) at step 0: 0.0926
# Seen so far: 128 samples, accuracy: 1.0000
# Validation loss: 0.1534
# Validation accuracy: 0.9379
#
# Start of epoch 144
# Training loss (for one batch) at step 0: 0.1453
# Seen so far: 128 samples, accuracy: 0.9844
# Validation loss: 0.1534
# Validation accuracy: 0.9379
#
# Start of epoch 145
# Training loss (for one batch) at step 0: 0.1075
# Seen so far: 128 samples, accuracy: 1.0000
# Validation loss: 0.1530
# Validation accuracy: 0.9379
#
# Start of epoch 146
# Training loss (for one batch) at step 0: 0.0886
# Seen so far: 128 samples, accuracy: 1.0000
# Validation loss: 0.1529
# Validation accuracy: 0.9379
#
# Start of epoch 147
# Training loss (for one batch) at step 0: 0.1274
# Seen so far: 128 samples, accuracy: 0.9766
# Validation loss: 0.1527
# Validation accuracy: 0.9379
#
# Start of epoch 148
# Training loss (for one batch) at step 0: 0.1321
# Seen so far: 128 samples, accuracy: 0.9688
# Validation loss: 0.1524
# Validation accuracy: 0.9379
#
# Start of epoch 149
# Training loss (for one batch) at step 0: 0.1073
# Seen so far: 128 samples, accuracy: 0.9922
# Validation loss: 0.1523
# Validation accuracy: 0.9379
#
# Start of epoch 150
# Training loss (for one batch) at step 0: 0.0980
# Seen so far: 128 samples, accuracy: 1.0000
# Validation loss: 0.1521
# Validation accuracy: 0.9379
#
# Start of epoch 151
# Training loss (for one batch) at step 0: 0.1098
# Seen so far: 128 samples, accuracy: 0.9922
# Validation loss: 0.1519
# Validation accuracy: 0.9379
#
# Start of epoch 152
# Training loss (for one batch) at step 0: 0.1229
# Seen so far: 128 samples, accuracy: 0.9922
# Validation loss: 0.1519
# Validation accuracy: 0.9418
#
# Start of epoch 153
# Training loss (for one batch) at step 0: 0.1159
# Seen so far: 128 samples, accuracy: 0.9844
# Validation loss: 0.1515
# Validation accuracy: 0.9379
#
# Start of epoch 154
# Training loss (for one batch) at step 0: 0.1167
# Seen so far: 128 samples, accuracy: 0.9922
# Validation loss: 0.1514
# Validation accuracy: 0.9379
#
# Start of epoch 155
# Training loss (for one batch) at step 0: 0.0995
# Seen so far: 128 samples, accuracy: 1.0000
# Validation loss: 0.1513
# Validation accuracy: 0.9379
#
# Start of epoch 156
# Training loss (for one batch) at step 0: 0.1156
# Seen so far: 128 samples, accuracy: 0.9766
# Validation loss: 0.1511
# Validation accuracy: 0.9418
#
# Start of epoch 157
# Training loss (for one batch) at step 0: 0.0885
# Seen so far: 128 samples, accuracy: 0.9922
# Validation loss: 0.1509
# Validation accuracy: 0.9418
#
# Start of epoch 158
# Training loss (for one batch) at step 0: 0.1270
# Seen so far: 128 samples, accuracy: 0.9766
# Validation loss: 0.1506
# Validation accuracy: 0.9379
#
# Start of epoch 159
# Training loss (for one batch) at step 0: 0.1228
# Seen so far: 128 samples, accuracy: 0.9922
# Validation loss: 0.1506
# Validation accuracy: 0.9418
#
# Start of epoch 160
# Training loss (for one batch) at step 0: 0.1119
# Seen so far: 128 samples, accuracy: 0.9922
# Validation loss: 0.1502
# Validation accuracy: 0.9379
#
# Start of epoch 161
# Training loss (for one batch) at step 0: 0.1281
# Seen so far: 128 samples, accuracy: 0.9766
# Validation loss: 0.1501
# Validation accuracy: 0.9379
#
# Start of epoch 162
# Training loss (for one batch) at step 0: 0.1037
# Seen so far: 128 samples, accuracy: 0.9922
# Validation loss: 0.1499
# Validation accuracy: 0.9379
#
# Start of epoch 163
# Training loss (for one batch) at step 0: 0.1146
# Seen so far: 128 samples, accuracy: 0.9922
# Validation loss: 0.1496
# Validation accuracy: 0.9379
#
# Start of epoch 164
# Training loss (for one batch) at step 0: 0.1086
# Seen so far: 128 samples, accuracy: 0.9922
# Validation loss: 0.1495
# Validation accuracy: 0.9379
#
# Start of epoch 165
# Training loss (for one batch) at step 0: 0.1150
# Seen so far: 128 samples, accuracy: 1.0000
# Validation loss: 0.1494
# Validation accuracy: 0.9379
#
# Start of epoch 166
# Training loss (for one batch) at step 0: 0.1078
# Seen so far: 128 samples, accuracy: 0.9922
# Validation loss: 0.1492
# Validation accuracy: 0.9379
#
# Start of epoch 167
# Training loss (for one batch) at step 0: 0.1049
# Seen so far: 128 samples, accuracy: 0.9766
# Validation loss: 0.1491
# Validation accuracy: 0.9379
#
# Start of epoch 168
# Training loss (for one batch) at step 0: 0.1101
# Seen so far: 128 samples, accuracy: 1.0000
# Validation loss: 0.1489
# Validation accuracy: 0.9379
#
# Start of epoch 169
# Training loss (for one batch) at step 0: 0.1107
# Seen so far: 128 samples, accuracy: 0.9922
# Validation loss: 0.1488
# Validation accuracy: 0.9379
#
# Start of epoch 170
# Training loss (for one batch) at step 0: 0.1315
# Seen so far: 128 samples, accuracy: 0.9766
# Validation loss: 0.1487
# Validation accuracy: 0.9379
#
# Start of epoch 171
# Training loss (for one batch) at step 0: 0.1192
# Seen so far: 128 samples, accuracy: 0.9844
# Validation loss: 0.1486
# Validation accuracy: 0.9418
#
# Start of epoch 172
# Training loss (for one batch) at step 0: 0.1044
# Seen so far: 128 samples, accuracy: 0.9766
# Validation loss: 0.1483
# Validation accuracy: 0.9379
#
# Start of epoch 173
# Training loss (for one batch) at step 0: 0.1097
# Seen so far: 128 samples, accuracy: 0.9766
# Validation loss: 0.1481
# Validation accuracy: 0.9379
#
# Start of epoch 174
# Training loss (for one batch) at step 0: 0.1337
# Seen so far: 128 samples, accuracy: 0.9688
# Validation loss: 0.1480
# Validation accuracy: 0.9379
#
# Start of epoch 175
# Training loss (for one batch) at step 0: 0.1064
# Seen so far: 128 samples, accuracy: 0.9844
# Validation loss: 0.1479
# Validation accuracy: 0.9418
#
# Start of epoch 176
# Training loss (for one batch) at step 0: 0.0944
# Seen so far: 128 samples, accuracy: 1.0000
# Validation loss: 0.1477
# Validation accuracy: 0.9379
#
# Start of epoch 177
# Training loss (for one batch) at step 0: 0.0877
# Seen so far: 128 samples, accuracy: 1.0000
# Validation loss: 0.1476
# Validation accuracy: 0.9379
#
# Start of epoch 178
# Training loss (for one batch) at step 0: 0.0933
# Seen so far: 128 samples, accuracy: 0.9922
# Validation loss: 0.1474
# Validation accuracy: 0.9379
#
# Start of epoch 179
# Training loss (for one batch) at step 0: 0.1276
# Seen so far: 128 samples, accuracy: 0.9844
# Validation loss: 0.1473
# Validation accuracy: 0.9379
#
# Start of epoch 180
# Training loss (for one batch) at step 0: 0.1074
# Seen so far: 128 samples, accuracy: 0.9844
# Validation loss: 0.1471
# Validation accuracy: 0.9379
#
# Start of epoch 181
# Training loss (for one batch) at step 0: 0.1002
# Seen so far: 128 samples, accuracy: 1.0000
# Validation loss: 0.1470
# Validation accuracy: 0.9379
#
# Start of epoch 182
# Training loss (for one batch) at step 0: 0.1099
# Seen so far: 128 samples, accuracy: 0.9922
# Validation loss: 0.1469
# Validation accuracy: 0.9379
#
# Start of epoch 183
# Training loss (for one batch) at step 0: 0.1130
# Seen so far: 128 samples, accuracy: 0.9844
# Validation loss: 0.1468
# Validation accuracy: 0.9379
#
# Start of epoch 184
# Training loss (for one batch) at step 0: 0.0875
# Seen so far: 128 samples, accuracy: 1.0000
# Validation loss: 0.1467
# Validation accuracy: 0.9379
#
# Start of epoch 185
# Training loss (for one batch) at step 0: 0.1207
# Seen so far: 128 samples, accuracy: 0.9766
# Validation loss: 0.1465
# Validation accuracy: 0.9379
#
# Start of epoch 186
# Training loss (for one batch) at step 0: 0.1030
# Seen so far: 128 samples, accuracy: 0.9922
# Validation loss: 0.1465
# Validation accuracy: 0.9418
#
# Start of epoch 187
# Training loss (for one batch) at step 0: 0.1311
# Seen so far: 128 samples, accuracy: 0.9922
# Validation loss: 0.1463
# Validation accuracy: 0.9379
#
# Start of epoch 188
# Training loss (for one batch) at step 0: 0.1228
# Seen so far: 128 samples, accuracy: 0.9844
# Validation loss: 0.1462
# Validation accuracy: 0.9418
#
# Start of epoch 189
# Training loss (for one batch) at step 0: 0.1243
# Seen so far: 128 samples, accuracy: 0.9844
# Validation loss: 0.1461
# Validation accuracy: 0.9379
#
# Start of epoch 190
# Training loss (for one batch) at step 0: 0.0928
# Seen so far: 128 samples, accuracy: 0.9844
# Validation loss: 0.1460
# Validation accuracy: 0.9379
#
# Start of epoch 191
# Training loss (for one batch) at step 0: 0.1134
# Seen so far: 128 samples, accuracy: 0.9844
# Validation loss: 0.1459
# Validation accuracy: 0.9379
#
# Start of epoch 192
# Training loss (for one batch) at step 0: 0.0929
# Seen so far: 128 samples, accuracy: 0.9844
# Validation loss: 0.1458
# Validation accuracy: 0.9418
#
# Start of epoch 193
# Training loss (for one batch) at step 0: 0.1020
# Seen so far: 128 samples, accuracy: 0.9922
# Validation loss: 0.1456
# Validation accuracy: 0.9379
#
# Start of epoch 194
# Training loss (for one batch) at step 0: 0.1097
# Seen so far: 128 samples, accuracy: 0.9922
# Validation loss: 0.1455
# Validation accuracy: 0.9379
#
# Start of epoch 195
# Training loss (for one batch) at step 0: 0.1259
# Seen so far: 128 samples, accuracy: 0.9844
# Validation loss: 0.1453
# Validation accuracy: 0.9379
#
# Start of epoch 196
# Training loss (for one batch) at step 0: 0.1214
# Seen so far: 128 samples, accuracy: 0.9766
# Validation loss: 0.1453
# Validation accuracy: 0.9418
#
# Start of epoch 197
# Training loss (for one batch) at step 0: 0.1034
# Seen so far: 128 samples, accuracy: 1.0000
# Validation loss: 0.1452
# Validation accuracy: 0.9379
#
# Start of epoch 198
# Training loss (for one batch) at step 0: 0.0884
# Seen so far: 128 samples, accuracy: 1.0000
# Validation loss: 0.1452
# Validation accuracy: 0.9418
#
# Start of epoch 199
# Training loss (for one batch) at step 0: 0.1015
# Seen so far: 128 samples, accuracy: 0.9766
# Validation loss: 0.1450
# Validation accuracy: 0.9379

# %%
model.set_weights(create_Siamese_network_model.best_weights)
model.save('/content/drive/MyDrive/A.아이/github/model_folder/model_siamese_neural_network.h5')

# %% [markdown]
# # Test

# %% [markdown]
# ## friends dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install mediapipe
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting mediapipe
#   Downloading mediapipe-0.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (33.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.9/33.9 MB 54.5 MB/s eta 0:00:00
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from mediapipe) (1.4.0)
# Requirement already satisfied: attrs>=19.1.0 in /usr/local/lib/python3.10/dist-packages (from mediapipe) (23.1.0)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.10/dist-packages (from mediapipe) (23.3.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mediapipe) (3.7.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from mediapipe) (1.22.4)
# Requirement already satisfied: opencv-contrib-python in /usr/local/lib/python3.10/dist-packages (from mediapipe) (4.7.0.72)
# Requirement already satisfied: protobuf<4,>=3.11 in /usr/local/lib/python3.10/dist-packages (from mediapipe) (3.20.3)
# Collecting sounddevice>=0.4.4 (from mediapipe)
#   Downloading sounddevice-0.4.6-py3-none-any.whl (31 kB)
# Requirement already satisfied: CFFI>=1.0 in /usr/local/lib/python3.10/dist-packages (from sounddevice>=0.4.4->mediapipe) (1.15.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe) (2.8.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.21)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->mediapipe) (1.16.0)
# Installing collected packages: sounddevice, mediapipe
# Successfully installed mediapipe-0.10.0 sounddevice-0.4.6

# %%
friends_path_first = '/content/drive/MyDrive/A.아이/images/friends_image/fist_image/'
friends_path_first_name = os.listdir(friends_path_first)

friends_path_second = '/content/drive/MyDrive/A.아이/images/friends_image/second_image/'
friends_path_second_name = os.listdir(friends_path_second)

# %%
import mediapipe as mp

mp_face_detection = mp.solutions.face_detection
image_friends_first_list = []
margin = 0.15  # Adjust this value to change the cropping margin

for name in friends_path_first_name :
    img = cv2.imread(friends_path_first + name)
    with mp_face_detection.FaceDetection(model_selection=1, min_detection_confidence=0.5) as face_detection:
            face = face_detection.process(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
            if face.detections:
                for i, detection in enumerate(face.detections):
                    # Get bounding box coordinates
                    box = detection.location_data.relative_bounding_box
                    ih, iw, _ = img.shape
                    x, y, w, h = int(box.xmin * iw), int(box.ymin * ih), int(box.width * iw), int(box.height * ih)
                    
                    # Calculate margins for x, y, w, h
                    mx = int(w * margin)
                    my = int(h * margin)
                    
                    # Crop the face with margins
                    face_image = img[y+my:y+h-my, x+mx:x+w-mx]
                    if face_image.size != 0:
                        # Resize the image to 105x105
                        face_image = cv2.resize(face_image, (105, 105))
                        face_image = cv2.cvtColor(face_image, cv2.COLOR_BGR2GRAY)
                        face_image = cv2.equalizeHist(face_image)
                    else :
                        break
            else :
                print('cant find face')
                continue
    image_friends_first_list.append(face_image)

for i in image_friends_first_list :
    cv2_imshow(i)
# Out:
# <PIL.Image.Image image mode=L size=105x105 at 0x7EFBAEE8FE20>
# <PIL.Image.Image image mode=L size=105x105 at 0x7EFB141D1D20>
# <PIL.Image.Image image mode=L size=105x105 at 0x7EFB1419D7B0>
# <PIL.Image.Image image mode=L size=105x105 at 0x7EFB1419D7B0>
# <PIL.Image.Image image mode=L size=105x105 at 0x7EFB1419D7B0>
# <PIL.Image.Image image mode=L size=105x105 at 0x7EFB1419D7B0>
# <PIL.Image.Image image mode=L size=105x105 at 0x7EFB1419D7B0>
# <PIL.Image.Image image mode=L size=105x105 at 0x7EFB1419D7B0>
# <PIL.Image.Image image mode=L size=105x105 at 0x7EFB1419D7B0>
# <PIL.Image.Image image mode=L size=105x105 at 0x7EFB1419D7B0>
# <PIL.Image.Image image mode=L size=105x105 at 0x7EFB1419D7B0>

# %%
mp_face_detection = mp.solutions.face_detection
image_friends_second_list = []
margin = 0.15  # Adjust this value to change the cropping margin

for name in friends_path_second_name :
    img = cv2.imread(friends_path_second + name)
    with mp_face_detection.FaceDetection(model_selection=1, min_detection_confidence=0.5) as face_detection:
            face = face_detection.process(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
            if face.detections:
                for i, detection in enumerate(face.detections):
                    # Get bounding box coordinates
                    box = detection.location_data.relative_bounding_box
                    ih, iw, _ = img.shape
                    x, y, w, h = int(box.xmin * iw), int(box.ymin * ih), int(box.width * iw), int(box.height * ih)
                    
                    # Calculate margins for x, y, w, h
                    mx = int(w * margin)
                    my = int(h * margin)
                    
                    # Crop the face with margins
                    face_image = img[y+my:y+h-my, x+mx:x+w-mx]
                    if face_image.size != 0:
                        # Resize the image to 105x105
                        face_image = cv2.resize(face_image, (105, 105))
                        face_image = cv2.cvtColor(face_image, cv2.COLOR_BGR2GRAY)
                        face_image = cv2.equalizeHist(face_image)
                    else :
                        break
            else :
                print('cant find face')
                continue
    image_friends_second_list.append(face_image)

for i in image_friends_second_list :
    cv2_imshow(i)
# Out:
# <PIL.Image.Image image mode=L size=105x105 at 0x7EFBAEE8EDA0>
# <PIL.Image.Image image mode=L size=105x105 at 0x7EFBAEE8EDA0>
# <PIL.Image.Image image mode=L size=105x105 at 0x7EFBAEE8EDA0>
# <PIL.Image.Image image mode=L size=105x105 at 0x7EFBAEE8EDA0>
# <PIL.Image.Image image mode=L size=105x105 at 0x7EFBAEE8EDA0>
# <PIL.Image.Image image mode=L size=105x105 at 0x7EFBAEE8EDA0>
# <PIL.Image.Image image mode=L size=105x105 at 0x7EFBAEE8EDA0>
# <PIL.Image.Image image mode=L size=105x105 at 0x7EFBAEE8EDA0>
# <PIL.Image.Image image mode=L size=105x105 at 0x7EFBAEE8EDA0>
# <PIL.Image.Image image mode=L size=105x105 at 0x7EFBAEE8EDA0>
# <PIL.Image.Image image mode=L size=105x105 at 0x7EFBAEE8EDA0>

# %%
image_friends_first_list = np.array(image_friends_first_list)
image_friends_second_list = np.array(image_friends_second_list)

image_friends_first_list.shape, image_friends_second_list.shape
# Out:
# ((11, 105, 105), (11, 105, 105))

# %% [markdown]
# ## test_model with friends

# %%
from tensorflow.keras.models import load_model
test_model = load_model('/content/drive/MyDrive/A.아이/github/models_folder/Image_Enhancement_model_siamese_neural_network.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/initializers/initializers.py:120: UserWarning: The initializer RandomNormal is unseeded and being called multiple times, which will return identical values each time (even if the initializer is unseeded). Please update your code to provide a seed to the initializer, or avoid using the same initalizer instance more than once.
#   warnings.warn(

# %%
def test_model_with_friends(index, image_friends_first_list, image_friends_second_list) : 
    # Your anchor image, let's use the first image from the test set as an example
    anchor_image = image_friends_first_list[index]  # Taking the first image from the first pair as an anchor image
    anchor_image = np.expand_dims(anchor_image, axis=0)  # Add batch dimension
    print(anchor_image.shape)

    # Variables to keep track of most similar images
    most_similar_images = []  # A list to keep track of the indices of the most similar images
    highest_similarities = []  # A list to keep track of the highest similarities

    # Images list from your data
    images_list = image_friends_second_list  # All second images from the test pairs

    # Iterate over images
    for i, image in enumerate(images_list):
        image = np.expand_dims(image, axis=0)  # Add batch dimension
        # Predict the similarity
        similarity = test_model.predict([anchor_image, image])[0][0]

        # If this image is more similar than the least similar image in most_similar_images, update most_similar_images
        if len(highest_similarities) < 5 or similarity > min(highest_similarities):
            if len(highest_similarities) == 5:
                # Remove the least similar image if we already have 5 images
                min_index = highest_similarities.index(min(highest_similarities))
                highest_similarities.pop(min_index)
                most_similar_images.pop(min_index)

            # Add new image
            highest_similarities.append(similarity)
            most_similar_images.append(i)  # Keeping track of the index rather than image
    # Show the most similar image index
    cv2_imshow(image_friends_first_list[index])
    cv2_imshow(image_friends_second_list[most_similar_images[0]])
    print('The similarity score is:', highest_similarities[0])
    cv2_imshow(image_friends_second_list[most_similar_images[1]])
    print('The similarity score is:', highest_similarities[1])
    cv2_imshow(image_friends_second_list[most_similar_images[2]])
    print('The similarity score is:', highest_similarities[2])
    cv2_imshow(image_friends_second_list[most_similar_images[3]])
    print('The similarity score is:', highest_similarities[3])
    cv2_imshow(image_friends_second_list[most_similar_images[4]])
    print('The similarity score is:', highest_similarities[4])

# %%
test_model_with_friends(3, image_friends_first_list, image_friends_second_list)
# Out:
# (1, 105, 105)
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# <PIL.Image.Image image mode=L size=105x105 at 0x7EFB08089F90>
# <PIL.Image.Image image mode=L size=105x105 at 0x7EFB08089F90>
# The similarity score is: 0.31581378
# <PIL.Image.Image image mode=L size=105x105 at 0x7EFBAF0EE5F0>
# The similarity score is: 0.1547337
# <PIL.Image.Image image mode=L size=105x105 at 0x7EFB080A5570>
# The similarity score is: 0.9936738
# <PIL.Image.Image image mode=L size=105x105 at 0x7EFBAEE53D60>
# The similarity score is: 0.2514255
# <PIL.Image.Image image mode=L size=105x105 at 0x7EFB08089F90>
# The similarity score is: 0.98582053

# %% [markdown]
# ## test model with testdata

# %%
# Your anchor image, let's use the first image from the test set as an example
anchor_image = x_test_pairs[index, 0, :, :]  # Taking the first image from the first pair as an anchor image
anchor_image = np.expand_dims(anchor_image, axis=0)  # Add batch dimension
print(anchor_image.shape)

# Variables to keep track of most similar images
most_similar_images = []  # A list to keep track of the indices of the most similar images
highest_similarities = []  # A list to keep track of the highest similarities

# Images list from your data
images_list = x_test_pairs[:, 1, :, :]  # All second images from the test pairs

# Iterate over images
for i, image in enumerate(images_list):
    image = np.expand_dims(image, axis=0)  # Add batch dimension
    # Predict the similarity
    similarity = test_model.predict([anchor_image, image])[0][0]

    # If this image is more similar than the least similar image in most_similar_images, update most_similar_images
    if len(highest_similarities) < 5 or similarity > min(highest_similarities):
        if len(highest_similarities) == 5:
            # Remove the least similar image if we already have 5 images
            min_index = highest_similarities.index(min(highest_similarities))
            highest_similarities.pop(min_index)
            most_similar_images.pop(min_index)

        # Add new image
        highest_similarities.append(similarity)
        most_similar_images.append(i)  # Keeping track of the index rather than image
# Show the most similar image index
cv2_imshow(x_test_pairs[index, 0, :, :])
cv2_imshow(x_test_pairs[most_similar_images[0], 1, :, :])
print('The similarity score is:', highest_similarities[0])
cv2_imshow(x_test_pairs[most_similar_images[1], 1, :, :])
print('The similarity score is:', highest_similarities[1])
cv2_imshow(x_test_pairs[most_similar_images[2], 1, :, :])
print('The similarity score is:', highest_similarities[2])
cv2_imshow(x_test_pairs[most_similar_images[3], 1, :, :])
print('The similarity score is:', highest_similarities[3])
cv2_imshow(x_test_pairs[most_similar_images[4], 1, :, :])
print('The similarity score is:', highest_similarities[4])
